# %%
import numpy as np
import cv2 as cv
img = cv.imread('lab3.jpg', 0)
rows, cols = img.shape
M = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, (cols, rows))
cv.imshow('img', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

img = cv.imread('lab3.jpg')

rows, cols, _ = img.shape
M = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, (cols, rows))
cv.imshow('original', img)
cv.imshow('img', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Define the translation values
tx, ty = 100, 50

# Create an empty array for the translated image
translated_img = np.zeros((rows, cols, channels), dtype=np.uint8)

# Perform the translation manually
for i in range(rows):
    for j in range(cols):
        new_x = i + ty
        new_y = j + tx
        if new_x < rows and new_y < cols:
            translated_img[new_x, new_y] = img[i, j]

# Display the original and translated images
cv.imshow('original', img)
cv.imshow('img', translated_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Define the translation values
tx, ty = 100, 50

# Create a larger canvas for the translated image
translated_img = np.zeros((rows + ty, cols + tx, channels), dtype=np.uint8)

# Perform the translation manually
for i in range(rows):
    for j in range(cols):
        new_x = i + ty
        new_y = j + tx
        if new_x < translated_img.shape[0] and new_y < translated_img.shape[1]:
            translated_img[new_x, new_y] = img[i, j]

# Display the original and translated images
cv.imshow('original', img)
cv.imshow('img', translated_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
img = cv.imread('lab3.jpg')
rows, cols, channels = img.shape
M = np.float32([[1, 0, 0], [0, -1, rows], [0, 0, 1]])
reflected_img = cv.warpPerspective(img, M, (cols, rows))
cv.imshow('img', reflected_img)
cv.imwrite('reflection_out.jpg', reflected_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
img = cv.imread('lab3.jpg',)
rows, cols, channels = img.shape
M = np.float32([[1, 0, 0], [0, -1, rows], [0, 0, 1]])
img_rotation = cv.warpAffine(img,
							cv.getRotationMatrix2D((cols/2, rows/2),
													30, 0.6),
							(cols, rows))
cv.imshow('img', img_rotation)
cv.imwrite('rotation_out.jpg', img_rotation)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Define the angle of rotation and the scaling factor
angle = 30
scale = 0.6

# Calculate the center of the image
center_x, center_y = cols / 2, rows / 2

# Convert the angle to radians
angle_rad = np.deg2rad(angle)

# Calculate the rotation matrix manually
M = np.float32([
    [scale * np.cos(angle_rad), -scale * np.sin(angle_rad), (1 - scale * np.cos(angle_rad)) * center_x + scale * np.sin(angle_rad) * center_y],
    [scale * np.sin(angle_rad), scale * np.cos(angle_rad), (1 - scale * np.cos(angle_rad)) * center_y - scale * np.sin(angle_rad) * center_x]
])

# Apply the affine transformation
img_rotation = cv.warpAffine(img, M, (cols, rows))

# Display the rotated image
cv.imshow('img', img_rotation)
cv.imwrite('rotation_out.jpg', img_rotation)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv


img = cv.imread('lab3.jpg')

rows, cols, channels = img.shape

new_rows, new_cols = 200, 250

img_shrinked = np.zeros((new_rows, new_cols, channels), dtype=np.uint8)


scale_x = cols / new_cols
scale_y = rows / new_rows

for i in range(new_rows):
    for j in range(new_cols):
        img_shrinked[i, j] = img[int(i * scale_y), int(j * scale_x)]

cv.imshow('img', img_shrinked)

scale_x = 1.5
scale_y = 1.5


new_rows = int(img_shrinked.shape[0] * scale_y)
new_cols = int(img_shrinked.shape[1] * scale_x)

# Create an empty array for the enlarged image
img_enlarged = np.zeros((new_rows, new_cols, channels), dtype=np.uint8)

# Perform the enlarging manually
for i in range(new_rows):
    for j in range(new_cols):
        img_enlarged[i, j] = img_shrinked[int(i / scale_y), int(j / scale_x)]

# Display the enlarged image
cv.imshow('img', img_enlarged)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv


img = cv.imread('lab3.jpg', 0)


rows, cols = img.shape


M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])


sheared_img = np.zeros((int(rows * 1.5), int(cols * 1.5)), dtype=np.uint8)


for i in range(rows):
    for j in range(cols):
        new_x = int(i + 0.5 * j)
        new_y = int(j)
        if new_x < sheared_img.shape[0] and new_y < sheared_img.shape[1]:
            sheared_img[new_x, new_y] = img[i, j]


cv.imshow('img', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in grayscale
img = cv.imread('lab3.jpg', 0)

# Unpack the shape into rows and cols
rows, cols = img.shape

# Define the shear transformation matrix manually
M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])

# Create a larger canvas for the sheared image
sheared_img = np.zeros((int(rows * 1.5), int(cols * 1.5)), dtype=np.uint8)

# Perform the shear transformation manually
for i in range(rows):
    for j in range(cols):
        new_x = int(i + 0.5 * j)
        new_y = int(j)
        if new_x < sheared_img.shape[0] and new_y < sheared_img.shape[1]:
            sheared_img[new_x, new_y] = img[i, j]

# Display the original and sheared images
cv.imshow('original', img)
cv.imshow('img', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Define the translation matrix
tx, ty = 50, 50  # Translation values
T = np.float32([[1, 0, tx], [0, 1, ty]])

# Apply the translation
translated_img = cv.warpAffine(img, T, (cols, rows))

# Define the angle of rotation and the scaling factor
angle = 30
scale = 0.6

# Calculate the center of the image
center_x, center_y = cols / 2, rows / 2

# Convert the angle to radians
angle_rad = np.deg2rad(angle)

# Calculate the rotation matrix manually
R = np.float32([
    [scale * np.cos(angle_rad), -scale * np.sin(angle_rad), (1 - scale * np.cos(angle_rad)) * center_x + scale * np.sin(angle_rad) * center_y],
    [scale * np.sin(angle_rad), scale * np.cos(angle_rad), (1 - scale * np.cos(angle_rad)) * center_y - scale * np.sin(angle_rad) * center_x]
])

# Apply the rotation with image cutting
rotated_img = cv.warpAffine(translated_img, R, (cols, rows))

# Display the rotated image
cv.imshow('img', rotated_img)
cv.imwrite('rotation_translation_out.jpg', rotated_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Define the translation matrix
tx, ty = 50, 50  # Translation values
T = np.float32([[1, 0, tx], [0, 1, ty]])

# Apply the translation
translated_img = cv.warpAffine(img, T, (cols, rows))

# Define the angle of rotation and the scaling factor
angle = 30
scale = 0.6

# Calculate the center of the image
center_x, center_y = cols / 2, rows / 2

# Convert the angle to radians
angle_rad = np.deg2rad(angle)

# Calculate the rotation matrix manually
R = np.float32([
    [scale * np.cos(angle_rad), -scale * np.sin(angle_rad), center_x * (1 - scale * np.cos(angle_rad)) + center_y * scale * np.sin(angle_rad)],
    [scale * np.sin(angle_rad), scale * np.cos(angle_rad), center_y * (1 - scale * np.cos(angle_rad)) - center_x * scale * np.sin(angle_rad)]
])

# Apply the rotation with image cutting
rotated_img = cv.warpAffine(translated_img, R, (cols, rows))

# Display the rotated image
cv.imshow('img', rotated_img)
cv.imwrite('rotation_translation_out.jpg', rotated_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Create an empty array for the reflected image
reflected_img = np.zeros((rows, cols, channels), dtype=np.uint8)

# Perform the reflection manually
for i in range(rows):
    for j in range(cols):
        reflected_img[i, cols - j - 1] = img[i, j]

# Display the reflected image
cv.imshow('img', reflected_img)
cv.imwrite('reflection_out.jpg', reflected_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in color
img = cv.imread('lab3.jpg')

# Unpack the shape into rows, cols, and channels
rows, cols, channels = img.shape

# Create an empty array for the reflected image
reflected_img = np.zeros((rows, cols, channels), dtype=np.uint8)

# Perform the reflection manually
for i in range(rows):
    for j in range(cols):
        reflected_img[i, cols - j - 1] = img[i, j]

# Display the original and reflected images
cv.imshow('original', img)
cv.imshow('img', reflected_img)
cv.imwrite('reflection_out.jpg', reflected_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in grayscale
img = cv.imread('lab3.jpg', 0)

# Unpack the shape into rows and cols
rows, cols = img.shape

# Define the shear transformation matrix manually
shear_factor = 0.5
M = np.float32([[1, shear_factor, 0], [0, 1, 0], [0, 0, 1]])

# Calculate the size of the new canvas to fit the sheared image
new_cols = int(cols + rows * shear_factor)
new_rows = rows

# Create a larger canvas for the sheared image
sheared_img = np.zeros((new_rows, new_cols), dtype=np.uint8)

# Perform the shear transformation manually
for i in range(rows):
    for j in range(cols):
        new_x = int(i + shear_factor * j)
        new_y = int(j)
        if new_x < sheared_img.shape[0] and new_y < sheared_img.shape[1]:
            sheared_img[new_x, new_y] = img[i, j]

# Display the original and sheared images
cv.imshow('original', img)
cv.imshow('sheared', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in grayscale
img = cv.imread('lab3.jpg', 0)

# Unpack the shape into rows and cols
rows, cols = img.shape

# Define the shear factor
shear_factor = 0.5

# Calculate the new canvas size to fit the sheared image
new_cols = int(cols + rows * abs(shear_factor))  # Width increases due to shear
new_rows = rows  # Height remains the same for horizontal shear

# Create a larger canvas for the sheared image
sheared_img = np.zeros((new_rows, new_cols), dtype=np.uint8)

# Perform the shear transformation manually
for i in range(rows):
    for j in range(cols):
        # Calculate the new position after shear
        new_x = int(i + shear_factor * j)
        new_y = j  # No vertical shear in this case

        # Ensure the new position is within the bounds of the new canvas
        if 0 <= new_x < new_rows and 0 <= new_y < new_cols:
            sheared_img[new_x, new_y] = img[i, j]

# Display the original and sheared images
cv.imshow('Original Image', img)
cv.imshow('Sheared Image', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv

# Read the image in grayscale
img = cv.imread('lab3.jpg', 0)

# Unpack the shape into rows and cols
rows, cols = img.shape  # rows = 1376, cols = 2200

# Define the shear factor
shear_factor = 0.5

# Calculate the new canvas size to fit the sheared image
new_cols = int(cols + rows * abs(shear_factor))  # New width = 2200 + 1376 * 0.5 = 2888
new_rows = rows  # Height remains the same (1376)

# Create a larger canvas for the sheared image
sheared_img = np.zeros((new_rows, new_cols), dtype=np.uint8)

# Perform the shear transformation manually
for i in range(rows):
    for j in range(cols):
        # Calculate the new position after shear
        new_x = int(i + shear_factor * j)
        new_y = j  # No vertical shear in this case

        # Ensure the new position is within the bounds of the new canvas
        if 0 <= new_x < new_rows and 0 <= new_y < new_cols:
            sheared_img[new_x, new_y] = img[i, j]

# Display the original and sheared images
cv.imshow('Original Image', img)
cv.imshow('Sheared Image', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
def shear_image(image, shear_factor_x, shear_factor_y):
    height, width = image.shape[:2]  # Get image dimensions
   
    # Calculate the min and max extents of the sheared image
    min_x, max_x, min_y, max_y = 0, 0, 0, 0
   
    for y in range(height):
        for x in range(width):
            new_x = x + shear_factor_x * y
            new_y = y + shear_factor_y * x
           
            # Track the min and max extents
            min_x = min(min_x, new_x)
            max_x = max(max_x, new_x)
            min_y = min(min_y, new_y)
            max_y = max(max_y, new_y)
   
    # Calculate new image size based on the extents
    new_width = int(max_x - min_x)
    new_height = int(max_y - min_y)
    sheared_image = np.zeros((new_height, new_width, image.shape[2]), dtype=image.dtype)
   
    # Calculate offsets to shift coordinates into the new image space
    offset_x = -min_x
    offset_y = -min_y

    # Apply shear transformation and place pixels in the new image
    for y in range(height):
        for x in range(width):
            new_x = int(x + shear_factor_x * y + offset_x)
            new_y = int(y + shear_factor_y * x + offset_y)
           
            # Ensure new coordinates are within the bounds of the new image
            if 0 <= new_x < new_width and 0 <= new_y < new_height:
                sheared_image[new_y, new_x] = image[y, x]
   
    return sheared_image

# Load an image (replace with the correct path to your image)
img = cv.imread('lab3.jpg',)

# Apply shearing with shear factors (example: shear_factor_x=0.5, shear_factor_y=0.5)
sheared_img = shear_image(img, shear_factor_x=0.5, shear_factor_y=0.5)

# Plot the original and sheared images
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Original image
axs[0].imshow(img)
axs[0].set_title('Original Image')
axs[0].axis('off')  # Hide axes

# Sheared image
axs[1].imshow(sheared_img)
axs[1].set_title('Sheared Image')
axs[1].axis('off')  # Hide axes

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
